# %%
from pyecharts import Bar,Timeline,Pie,Overlap

# %%
attr = ['less than 40m²','40m² to 69.9m²','70m² to 99.9m²','100m² to 159.9m²','160m² or above']
bar1 = Bar("2008 Hong Kong Property Price", title_text_size = 10)
bar1.add('Hong Kong Island', attr, [63997,72563,96537,123335,172166],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar1.add('Kowloon', attr, [42952,53543,83318,102660,137295],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar1.add('New Territory', attr, [37705,38255,48727,58875,74113],yaxis_formatter = '/m²',yaxis_label_textsize = 10)



bar2 = Bar("2009 Hong Kong Property Price", title_text_size = 10)
bar2.add('Hong Kong Island', attr, [61832,71459,95288,120617,164169],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar2.add('Kowloon', attr, [44190,55338,85613,101356,145137],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar2.add('New Territory', attr, [39215,39468,49189,57554,69225],yaxis_formatter = '/m²',yaxis_label_textsize = 10)



bar3 = Bar("2010 Hong Kong Property Price", title_text_size = 10)
bar3.add('Hong Kong Island', attr, [75892,86553,113073,147970,207171],yaxis_name = '/m²',yaxis_label_textsize = 10)
bar3.add('Kowloon', attr, [55661,69728,107486,133704,165494],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar3.add('New Territory', attr, [48206,47127,59190,66379,74706],yaxis_formatter = '/m²',yaxis_label_textsize = 10)



bar4 = Bar("2011 Hong Kong Property Price", title_text_size = 10)
bar4.add('Hong Kong Island', attr,[93497,101779,135355,167939,234951],yaxis_formatter  = '/m²',yaxis_label_textsize = 10)
bar4.add('Kowloon', attr, [67594,81941,123511,154327,214806],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar4.add('New Territory', attr, [58093,56305,68022,73228,80178],yaxis_formatter = '/m²',yaxis_label_textsize = 10)



bar5 = Bar("2012 Hong Kong Property Price", title_text_size = 10)
bar5.add('Hong Kong Island', attr,[108326,112158,142070,177673,259380],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar5.add('Kowloon', attr, [79928,92997,128259,158106,185727],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar5.add('New Territory', attr, [67828,65319,75416,76953,87598],yaxis_formatter = '/m²',yaxis_label_textsize = 10)



bar6 = Bar("2013 Hong Kong Property Price", title_text_size = 10)
bar6.add('Hong Kong Island', attr,[123304,126642,159480,184830,255215],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar6.add('Kowloon', attr, [94808,103401,138823,157700,194285],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar6.add('New Territory', attr, [83132,75449,85640,79818,78664],yaxis_formatter = '/m²',yaxis_label_textsize = 10)



bar7 = Bar("2014 Hong Kong Property Price", title_text_size = 10)
bar7.add('Hong Kong Island', attr,[128912,129629,153720,183962,249984],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar7.add('Kowloon', attr, [104403,108820,138586,160259,235620],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar7.add('New Territory', attr, [91436,81476,89607,85479,73677],yaxis_formatter = '/m²',yaxis_label_textsize = 10)



bar8 = Bar("2015 Hong Kong Property Price", title_text_size = 10)
bar8.add('Hong Kong Island', attr,[146515,147969,171848,198709,238707],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar8.add('Kowloon', attr, [117955,120994,148980,166958,206485],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar8.add('New Territory', attr, [107763,94297,101364,96962,88734],yaxis_formatter = '/m²',yaxis_label_textsize = 10)



bar9 = Bar("2016 Hong Kong Property Price", title_text_size = 10)
bar9.add('Hong Kong Island', attr,[137558,140103,162731,197622,238737],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar9.add('Kowloon', attr, [112486,115792,149335,167980,231700],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar9.add('New Territory', attr, [102680,91942,97811,94692,82547],yaxis_formatter = '/m²',yaxis_label_textsize = 10)



bar10 = Bar("2017 Hong Kong Property Price", title_text_size = 10)
bar10.add('Hong Kong Island', attr,[158328,160797,186040,215978,251606],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar10.add('Kowloon', attr, [130497,131093,163498,179974,273418],yaxis_formatter = '/m²',yaxis_label_textsize = 10)
bar10.add('New Territory', attr, [121667,106577,112867,103235,91648],yaxis_formatter = '/m²',yaxis_label_textsize = 10)



timeline = Timeline(is_auto_play=True, timeline_bottom=0)
timeline.add(bar1, '2008 年')
timeline.add(bar2, '2009 年')
timeline.add(bar3, '2010 年')
timeline.add(bar4, '2011 年')
timeline.add(bar5, '2012 年')
timeline.add(bar6, '2013 年')
timeline.add(bar7, '2014 年')
timeline.add(bar8, '2015 年')
timeline.add(bar9, '2016 年')
timeline.add(bar10, '2017 年')
timeline.render('timebar.html')
